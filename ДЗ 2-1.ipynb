# %%
# %reload_ext sql
# %sql sqlite:///chinook.db
# Out:
# 'Connected: None@chinook.db'

# %% [markdown]
# # Задание 1
#
# Необходимо вывести названия треков, которые были приобретены компаниями, которые обслуживаются сотрудниками, нанятыми после 1 сентября 2002 года.

# %%
# %%sql
# select tracks.Name
# from tracks join invoice_items
# on tracks.TrackId = invoice_items.TrackId
# join invoices on invoice_items.InvoiceId = invoices.InvoiceId
# join customers on customers.CustomerId = invoices.InvoiceId
# where customers.CustomerId =
# (select  customers.CustomerId
# from customers join employees
# on customers.SupportRepId = employees.EmployeeId
# where employees.HireDate > '2002-09-01')
# Out:
# Done.
# [('Right Through You',),
#  ('Not The Doctor',),
#  ('Bleed The Freak',),
#  ('Confusion',),
#  ('Por Causa De Você',),
#  ('Angela',),
#  ('Master Of Puppets',),
#  ('Welcome Home (Sanitarium)',),
#  ('Set It Off',)]

# %% [markdown]
# ## Задание 2
# Вывести общую стоимость и продолжительность каждого плейлиста.

# %%
# %%sql
# select playlists.Name , round(sum(tracks.UnitPrice),-1) as sum_1 , round(sum(tracks.Milliseconds),-1) as sum_2
# from playlists left join playlist_track on playlists.PlaylistId = playlist_track.PlaylistId
# left join tracks on playlist_track.TrackId = tracks.TrackId
# group by playlists.Name
# Out:
# Done.
# [('90’s Music', 1462.0, 398705153.0),
#  ('Audiobooks', None, None),
#  ('Brazilian Music', 39.0, 9486559.0),
#  ('Classical', 74.0, 21770592.0),
#  ('Classical 101 - Deep Cuts', 25.0, 6755730.0),
#  ('Classical 101 - Next Steps', 25.0, 7575051.0),
#  ('Classical 101 - The Basics', 25.0, 7439811.0),
#  ('Grunge', 15.0, 4122018.0),
#  ('Heavy Metal Classic', 26.0, 8206312.0),
#  ('Movies', None, None),
#  ('Music', 6514.0, 1755366166.0),
#  ('Music Videos', 1.0, 294294.0),
#  ('On-The-Go 1', 1.0, 197459.0),
#  ('TV Shows', 848.0, 1002189914.0)]

# %% [markdown]
# ## Задание 3
# Для каждого артиста определить все жанры песен, которые у него есть и количество песен по каждому жанру.

# %%
# %%sql
# select artists.Name, genres.Name as genre_Name, count(tracks.GenreId) from
# artists join albums on artists.ArtistId = albums.ArtistId
# join tracks on albums.AlbumId = tracks.AlbumId
# join genres on genres.GenreId = tracks.GenreId
# group by artists.Name
# Out:
# Done.
# [('AC/DC', 'Rock', 18),
#  ('Aaron Copland & London Symphony Orchestra', 'Classical', 1),
#  ('Aaron Goldberg', 'Jazz', 1),
#  ('Academy of St. Martin in the Fields & Sir Neville Marriner', 'Classical', 2),
#  ('Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', 'Classical', 1),
#  ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 'Classical', 1),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 'Classical', 1),
#  ('Accept', 'Rock', 4),
#  ('Adrian Leaper & Doreen de Feis', 'Classical', 1),
#  ('Aerosmith', 'Rock', 15),
#  ('Aisha Duo', 'Jazz', 2),
#  ('Alanis Morissette', 'Rock', 13),
#  ('Alberto Turco & Nova Schola Gregoriana', 'Classical', 1),
#  ('Alice In Chains', 'Rock', 12),
#  ('Amy Winehouse', 'Pop', 23),
#  ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', 'Classical', 1),
#  ('Antal Doráti & London Symphony Orchestra', 'Classical', 1),
#  ('Antônio Carlos Jobim', 'Latin', 31),
#  ('Apocalyptica', 'Metal', 8),
#  ('Aquaman', 'TV Shows', 1),
#  ('Audioslave', 'Alternative', 40),
#  ('BackBeat', 'Rock And Roll', 12),
#  ('Barry Wordsworth & BBC Concert Orchestra', 'Classical', 1),
#  ('Battlestar Galactica', 'Sci Fi & Fantasy', 20),
#  ('Battlestar Galactica (Classic)', 'Sci Fi & Fantasy', 24),
#  ('Berliner Philharmoniker & Hans Rosbaud', 'Classical', 1),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 'Classical', 3),
#  ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', 'Classical', 1),
#  ('Billy Cobham', 'Jazz', 8),
#  ('Black Label Society', 'Metal', 18),
#  ('Black Sabbath', 'Metal', 17),
#  ('Body Count', 'Alternative & Punk', 17),
#  ('Boston Symphony Orchestra & Seiji Ozawa', 'Classical', 1),
#  ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', 'Classical', 1),
#  ('Bruce Dickinson', 'Metal', 11),
#  ('Buddy Guy', 'Blues', 11),
#  ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', 'Classical', 1),
#  ('Caetano Veloso', 'Latin', 21),
#  ('Cake', 'Alternative', 1),
#  ('Calexico', 'Alternative', 1),
#  ("Charles Dutoit & L'Orchestre Symphonique de Montréal", 'Classical', 1),
#  ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 'Classical', 1),
#  ('Chicago Symphony Orchestra & Fritz Reiner', 'Classical', 1),
#  ('Chico Buarque', 'Latin', 34),
#  ('Chico Science & Nação Zumbi', 'Latin', 36),
#  ('Choir Of Westminster Abbey & Simon Preston', 'Classical', 1),
#  ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 'Classical', 1),
#  ('Chris Cornell', 'Alternative', 14),
#  ("Christopher O'Riley", 'Classical', 1),
#  ('Cidade Negra', 'Reggae', 31),
#  ('Cláudio Zoli', 'Latin', 10),
#  ('Creedence Clearwater Revival', 'Rock', 40),
#  ('Cássia Eller', 'Latin', 30),
#  ('David Coverdale', 'Rock', 12),
#  ('Deep Purple', 'Rock', 92),
#  ('Def Leppard', 'Rock', 16),
#  ('Dennis Chambers', 'Jazz', 9),
#  ('Djavan', 'Latin', 26),
#  ('Dread Zeppelin', 'Rock', 1),
#  ('Ed Motta', 'Latin', 14),
#  ('Edo de Waart & San Francisco Symphony', 'Classical', 1),
#  ('Elis Regina', 'Latin', 14),
#  ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 'Classical', 1),
#  ('Emerson String Quartet', 'Classical', 1),
#  ('English Concert & Trevor Pinnock', 'Classical', 2),
#  ('Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 'Classical', 1),
#  ('Eric Clapton', 'Latin', 48),
#  ('Eugene Ormandy', 'Classical', 3),
#  ('Faith No More', 'Alternative & Punk', 52),
#  ('Falamansa', 'Latin', 14),
#  ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 'Classical', 1),
#  ('Foo Fighters', 'Rock', 44),
#  ('Frank Sinatra', 'Easy Listening', 24),
#  ('Frank Zappa & Captain Beefheart', 'Rock', 9),
#  ('Fretwork', 'Classical', 1),
#  ('Funk Como Le Gusta', 'Latin', 16),
#  ('Gene Krupa', 'Jazz', 22),
#  ('Gerald Moore', 'Classical', 1),
#  ('Gilberto Gil', 'Jazz', 32),
#  ('Godsmack', 'Metal', 12),
#  ('Gonzaguinha', 'Latin', 14),
#  ('Green Day', 'Alternative & Punk', 34),
#  ("Guns N' Roses", 'Metal', 42),
#  ('Gustav Mahler', 'Classical', 1),
#  ('Göteborgs Symfoniker & Neeme Järvi', 'Classical', 1),
#  ('Habib Koité and Bamada', 'World', 2),
#  ('Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', 'Classical', 1),
#  ('Heroes', 'Drama', 23),
#  ('Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer', 'Classical', 1),
#  ('House Of Pain', 'Hip Hop/Rap', 19),
#  ('Incognito', 'Jazz', 13),
#  ('Iron Maiden', 'Rock', 213),
#  ('Itzhak Perlman', 'Classical', 1),
#  ('JET', 'Alternative & Punk', 13),
#  ('James Brown', 'R&B/Soul', 20),
#  ('James Levine', 'Classical', 1),
#  ('Jamiroquai', 'Electronica/Dance', 32),
#  ('Jimi Hendrix', 'Rock', 17),
#  ('Joe Satriani', 'Rock', 10),
#  ('Jorge Ben', 'Latin', 14),
#  ('Jota Quest', 'Latin', 12),
#  ('João Suplicy', 'World', 14),
#  ('Judas Priest', 'Metal', 16),
#  ('Julian Bream', 'Classical', 1),
#  ('Karsh Kale', 'Electronica/Dance', 2),
#  ("Kent Nagano and Orchestre de l'Opéra de Lyon", 'Classical', 1),
#  ('Kiss', 'Rock', 35),
#  ('Led Zeppelin', 'Rock', 114),
#  ('Legião Urbana', 'Latin', 31),
#  ('Lenny Kravitz', 'Metal', 57),
#  ('Leonard Bernstein & New York Philharmonic', 'Classical', 1),
#  ('Les Arts Florissants & William Christie', 'Classical', 1),
#  ('London Symphony Orchestra & Sir Charles Mackerras', 'Classical', 1),
#  ('Lost', 'Drama', 92),
#  ('Luciana Souza/Romero Lubambo', 'Latin', 1),
#  ('Luciano Pavarotti', 'Classical', 1),
#  ('Lulu Santos', 'Latin', 28),
#  ('Marcos Valle', 'Latin', 17),
#  ('Marillion', 'Rock', 10),
#  ('Marisa Monte', 'Latin', 18),
#  ('Martin Roscoe', 'Classical', 1),
#  ('Marvin Gaye', 'R&B/Soul', 18),
#  ('Maurizio Pollini', 'Classical', 1),
#  ('Mela Tenenbaum, Pro Musica Prague & Richard Kapp', 'Classical', 1),
#  ('Men At Work', 'Rock', 10),
#  ('Metallica', 'Metal', 112),
#  ('Michael Tilson Thomas & San Francisco Symphony', 'Classical', 2),
#  ('Michele Campanella', 'Classical', 1),
#  ('Miles Davis', 'Jazz', 37),
#  ('Milton Nascimento', 'Latin', 26),
#  ('Motörhead', 'Metal', 15),
#  ('Mônica Marianno', 'World', 12),
#  ('Mötley Crüe', 'Metal', 17),
#  ('Nash Ensemble', 'Classical', 1),
#  ('Nicolaus Esterhazy Sinfonia', 'Classical', 1),
#  ('Nirvana', 'Rock', 29),
#  ('O Rappa', 'Electronica/Dance', 17),
#  ('O Terço', 'Rock', 15),
#  ('Olodum', 'Latin', 14),
#  ('Orchestra of The Age of Enlightenment', 'Classical', 1),
#  ('Orchestre Révolutionnaire et Romantique & John Eliot Gardiner', 'Classical', 1),
#  ('Os Mutantes', 'Alternative & Punk', 14),
#  ('Os Paralamas Do Sucesso', 'Latin', 49),
#  ('Otto Klemperer & Philharmonia Orchestra', 'Classical', 1),
#  ('Ozzy Osbourne', 'Rock', 32),
#  ('Page & Plant', 'Rock', 12),
#  ('Passengers', 'Soundtrack', 14),
#  ("Paul D'Ianno", 'Rock', 10),
#  ('Pearl Jam', 'Rock', 67),
#  ('Philharmonia Orchestra & Sir Neville Marriner', 'Classical', 1),
#  ('Philip Glass Ensemble', 'Soundtrack', 1),
#  ('Pink Floyd', 'Rock', 9),
#  ('Planet Hemp', 'Hip Hop/Rap', 16),
#  ('Queen', 'Rock', 45),
#  ('R.E.M.', 'Alternative & Punk', 41),
#  ('R.E.M. Feat. Kate Pearson', 'Alternative & Punk', 11),
#  ('Raimundos', 'Alternative & Punk', 10),
#  ('Raul Seixas', 'Rock', 14),
#  ('Red Hot Chili Peppers', 'Rock', 48),
#  ('Richard Marlow & The Choir of Trinity College, Cambridge', 'Classical', 1),
#  ('Roger Norrington, London Classical Players', 'Classical', 1),
#  ('Royal Philharmonic Orchestra & Sir Thomas Beecham', 'Classical', 1),
#  ('Rush', 'Rock', 14),
#  ('Santana', 'Rock', 27),
#  ('Scholars Baroque Ensemble', 'Classical', 1),
#  ('Scorpions', 'Rock', 12),
#  ('Sergei Prokofiev & Yuri Temirkanov', 'Classical', 1),
#  ('Sir Georg Solti & Wiener Philharmoniker', 'Classical', 1),
#  ('Sir Georg Solti, Sumi Jo & Wiener Philharmoniker', 'Opera', 1),
#  ('Skank', 'Rock', 23),
#  ('Smashing Pumpkins', 'Alternative & Punk', 34),
#  ('Soundgarden', 'Rock', 17),
#  ('Spyro Gyra', 'Jazz', 21),
#  ('Stevie Ray Vaughan & Double Trouble', 'Blues', 10),
#  ('Stone Temple Pilots', 'Rock', 12),
#  ('System Of A Down', 'Metal', 11),
#  ('Temple of the Dog', 'Alternative', 10),
#  ('Terry Bozzio, Tony Levin & Steve Stevens', 'Rock', 7),
#  ('The 12 Cellists of The Berlin Philharmonic', 'Classical', 1),
#  ('The Black Crowes', 'Blues', 19),
#  ('The Clash', 'Alternative & Punk', 18),
#  ('The Cult', 'Rock', 30),
#  ('The Doors', 'Rock', 11),
#  ("The King's Singers", 'Classical', 2),
#  ('The Office', 'Comedy', 53),
#  ('The Police', 'Rock', 14),
#  ('The Posies', 'Rock', 2),
#  ('The Rolling Stones', 'Rock', 41),
#  ('The Tea Party', 'Alternative & Punk', 26),
#  ('The Who', 'Rock', 20),
#  ('Tim Maia', 'Latin', 30),
#  ('Titãs', 'Alternative & Punk', 38),
#  ('Ton Koopman', 'Classical', 1),
#  ('Toquinho & Vinícius', 'Bossa Nova', 15),
#  ('U2', 'Pop', 135),
#  ('UB40', 'Reggae', 14),
#  ('Van Halen', 'Rock', 52),
#  ('Various Artists', 'Latin', 56),
#  ('Velvet Revolver', 'Rock', 13),
#  ('Vinícius De Moraes', 'Latin', 15),
#  ('Wilhelm Kempff', 'Classical', 1),
#  ('Yehudi Menuhin', 'Classical', 1),
#  ('Yo-Yo Ma', 'Classical', 1),
#  ('Zeca Pagodinho', 'Latin', 19)]

# %% [markdown]
# ## Задание 4
# Для каждого артиста найти жанр, по которому он заработал наибольшее количество денег, а также вывести соотношение общей суммы, заработанной артистом по всем другим жанрам к общей сумме заработанных денег.

# %%
# %%sql
# select artists.Name , sum(tracks.UnitPrice) as sum_1
# from artists join albums on artists.ArtistId = albums.ArtistId
# join tracks on tracks.AlbumId = albums.AlbumId
# join genres on genres.GenreId = tracks.GenreId
# group by artists.Name
# Out:
# Done.
# [('AC/DC', 17.82),
#  ('Aaron Copland & London Symphony Orchestra', 0.99),
#  ('Aaron Goldberg', 0.99),
#  ('Academy of St. Martin in the Fields & Sir Neville Marriner', 1.98),
#  ('Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', 0.99),
#  ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 0.99),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 0.99),
#  ('Accept', 3.96),
#  ('Adrian Leaper & Doreen de Feis', 0.99),
#  ('Aerosmith', 14.850000000000001),
#  ('Aisha Duo', 1.98),
#  ('Alanis Morissette', 12.870000000000001),
#  ('Alberto Turco & Nova Schola Gregoriana', 0.99),
#  ('Alice In Chains', 11.88),
#  ('Amy Winehouse', 22.769999999999992),
#  ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', 0.99),
#  ('Antal Doráti & London Symphony Orchestra', 0.99),
#  ('Antônio Carlos Jobim', 30.68999999999998),
#  ('Apocalyptica', 7.920000000000001),
#  ('Aquaman', 1.99),
#  ('Audioslave', 39.599999999999994),
#  ('BackBeat', 11.88),
#  ('Barry Wordsworth & BBC Concert Orchestra', 0.99),
#  ('Battlestar Galactica', 39.8),
#  ('Battlestar Galactica (Classic)', 47.760000000000005),
#  ('Berliner Philharmoniker & Hans Rosbaud', 0.99),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 2.9699999999999998),
#  ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', 0.99),
#  ('Billy Cobham', 7.920000000000001),
#  ('Black Label Society', 17.82),
#  ('Black Sabbath', 16.830000000000002),
#  ('Body Count', 16.830000000000002),
#  ('Boston Symphony Orchestra & Seiji Ozawa', 0.99),
#  ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', 0.99),
#  ('Bruce Dickinson', 10.89),
#  ('Buddy Guy', 10.89),
#  ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', 0.99),
#  ('Caetano Veloso', 20.789999999999996),
#  ('Cake', 0.99),
#  ('Calexico', 0.99),
#  ("Charles Dutoit & L'Orchestre Symphonique de Montréal", 0.99),
#  ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 0.99),
#  ('Chicago Symphony Orchestra & Fritz Reiner', 0.99),
#  ('Chico Buarque', 33.65999999999998),
#  ('Chico Science & Nação Zumbi', 35.639999999999986),
#  ('Choir Of Westminster Abbey & Simon Preston', 0.99),
#  ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 0.99),
#  ('Chris Cornell', 13.860000000000001),
#  ("Christopher O'Riley", 0.99),
#  ('Cidade Negra', 30.68999999999998),
#  ('Cláudio Zoli', 9.9),
#  ('Creedence Clearwater Revival', 39.599999999999994),
#  ('Cássia Eller', 29.69999999999998),
#  ('David Coverdale', 11.88),
#  ('Deep Purple', 91.0799999999999),
#  ('Def Leppard', 15.840000000000002),
#  ('Dennis Chambers', 8.91),
#  ('Djavan', 25.739999999999988),
#  ('Dread Zeppelin', 0.99),
#  ('Ed Motta', 13.860000000000001),
#  ('Edo de Waart & San Francisco Symphony', 0.99),
#  ('Elis Regina', 13.860000000000001),
#  ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 0.99),
#  ('Emerson String Quartet', 0.99),
#  ('English Concert & Trevor Pinnock', 1.98),
#  ('Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 0.99),
#  ('Eric Clapton', 47.52000000000001),
#  ('Eugene Ormandy', 2.9699999999999998),
#  ('Faith No More', 51.48000000000002),
#  ('Falamansa', 13.860000000000001),
#  ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 0.99),
#  ('Foo Fighters', 43.56),
#  ('Frank Sinatra', 23.75999999999999),
#  ('Frank Zappa & Captain Beefheart', 8.91),
#  ('Fretwork', 0.99),
#  ('Funk Como Le Gusta', 15.840000000000002),
#  ('Gene Krupa', 21.779999999999994),
#  ('Gerald Moore', 0.99),
#  ('Gilberto Gil', 31.67999999999998),
#  ('Godsmack', 11.88),
#  ('Gonzaguinha', 13.860000000000001),
#  ('Green Day', 33.65999999999998),
#  ("Guns N' Roses", 41.58),
#  ('Gustav Mahler', 0.99),
#  ('Göteborgs Symfoniker & Neeme Järvi', 0.99),
#  ('Habib Koité and Bamada', 1.98),
#  ('Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', 0.99),
#  ('Heroes', 45.77),
#  ('Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer', 0.99),
#  ('House Of Pain', 18.81),
#  ('Incognito', 12.870000000000001),
#  ('Iron Maiden', 210.87000000000046),
#  ('Itzhak Perlman', 0.99),
#  ('JET', 12.870000000000001),
#  ('James Brown', 19.799999999999997),
#  ('James Levine', 0.99),
#  ('Jamiroquai', 31.67999999999998),
#  ('Jimi Hendrix', 16.830000000000002),
#  ('Joe Satriani', 9.9),
#  ('Jorge Ben', 13.860000000000001),
#  ('Jota Quest', 11.88),
#  ('João Suplicy', 13.860000000000001),
#  ('Judas Priest', 15.840000000000002),
#  ('Julian Bream', 0.99),
#  ('Karsh Kale', 1.98),
#  ("Kent Nagano and Orchestre de l'Opéra de Lyon", 0.99),
#  ('Kiss', 34.649999999999984),
#  ('Led Zeppelin', 112.85999999999979),
#  ('Legião Urbana', 30.68999999999998),
#  ('Lenny Kravitz', 56.43000000000003),
#  ('Leonard Bernstein & New York Philharmonic', 0.99),
#  ('Les Arts Florissants & William Christie', 0.99),
#  ('London Symphony Orchestra & Sir Charles Mackerras', 0.99),
#  ('Lost', 183.0800000000001),
#  ('Luciana Souza/Romero Lubambo', 0.99),
#  ('Luciano Pavarotti', 0.99),
#  ('Lulu Santos', 27.719999999999985),
#  ('Marcos Valle', 16.830000000000002),
#  ('Marillion', 9.9),
#  ('Marisa Monte', 17.82),
#  ('Martin Roscoe', 0.99),
#  ('Marvin Gaye', 17.82),
#  ('Maurizio Pollini', 0.99),
#  ('Mela Tenenbaum, Pro Musica Prague & Richard Kapp', 0.99),
#  ('Men At Work', 9.9),
#  ('Metallica', 110.8799999999998),
#  ('Michael Tilson Thomas & San Francisco Symphony', 1.98),
#  ('Michele Campanella', 0.99),
#  ('Miles Davis', 36.62999999999999),
#  ('Milton Nascimento', 25.739999999999988),
#  ('Motörhead', 14.850000000000001),
#  ('Mônica Marianno', 11.88),
#  ('Mötley Crüe', 16.830000000000002),
#  ('Nash Ensemble', 0.99),
#  ('Nicolaus Esterhazy Sinfonia', 0.99),
#  ('Nirvana', 28.709999999999983),
#  ('O Rappa', 16.830000000000002),
#  ('O Terço', 14.850000000000001),
#  ('Olodum', 13.860000000000001),
#  ('Orchestra of The Age of Enlightenment', 0.99),
#  ('Orchestre Révolutionnaire et Romantique & John Eliot Gardiner', 0.99),
#  ('Os Mutantes', 13.860000000000001),
#  ('Os Paralamas Do Sucesso', 48.51000000000001),
#  ('Otto Klemperer & Philharmonia Orchestra', 0.99),
#  ('Ozzy Osbourne', 31.67999999999998),
#  ('Page & Plant', 11.88),
#  ('Passengers', 13.860000000000001),
#  ("Paul D'Ianno", 9.9),
#  ('Pearl Jam', 66.33000000000003),
#  ('Philharmonia Orchestra & Sir Neville Marriner', 0.99),
#  ('Philip Glass Ensemble', 0.99),
#  ('Pink Floyd', 8.91),
#  ('Planet Hemp', 15.840000000000002),
#  ('Queen', 44.550000000000004),
#  ('R.E.M.', 40.589999999999996),
#  ('R.E.M. Feat. Kate Pearson', 10.89),
#  ('Raimundos', 9.9),
#  ('Raul Seixas', 13.860000000000001),
#  ('Red Hot Chili Peppers', 47.52000000000001),
#  ('Richard Marlow & The Choir of Trinity College, Cambridge', 0.99),
#  ('Roger Norrington, London Classical Players', 0.99),
#  ('Royal Philharmonic Orchestra & Sir Thomas Beecham', 0.99),
#  ('Rush', 13.860000000000001),
#  ('Santana', 26.729999999999986),
#  ('Scholars Baroque Ensemble', 0.99),
#  ('Scorpions', 11.88),
#  ('Sergei Prokofiev & Yuri Temirkanov', 0.99),
#  ('Sir Georg Solti & Wiener Philharmoniker', 0.99),
#  ('Sir Georg Solti, Sumi Jo & Wiener Philharmoniker', 0.99),
#  ('Skank', 22.769999999999992),
#  ('Smashing Pumpkins', 33.65999999999998),
#  ('Soundgarden', 16.830000000000002),
#  ('Spyro Gyra', 20.789999999999996),
#  ('Stevie Ray Vaughan & Double Trouble', 9.9),
#  ('Stone Temple Pilots', 11.88),
#  ('System Of A Down', 10.89),
#  ('Temple of the Dog', 9.9),
#  ('Terry Bozzio, Tony Levin & Steve Stevens', 6.930000000000001),
#  ('The 12 Cellists of The Berlin Philharmonic', 0.99),
#  ('The Black Crowes', 18.81),
#  ('The Clash', 17.82),
#  ('The Cult', 29.69999999999998),
#  ('The Doors', 10.89),
#  ("The King's Singers", 1.98),
#  ('The Office', 105.46999999999991),
#  ('The Police', 13.860000000000001),
#  ('The Posies', 1.98),
#  ('The Rolling Stones', 40.589999999999996),
#  ('The Tea Party', 25.739999999999988),
#  ('The Who', 19.799999999999997),
#  ('Tim Maia', 29.69999999999998),
#  ('Titãs', 37.61999999999999),
#  ('Ton Koopman', 0.99),
#  ('Toquinho & Vinícius', 14.850000000000001),
#  ('U2', 133.64999999999975),
#  ('UB40', 13.860000000000001),
#  ('Van Halen', 51.48000000000002),
#  ('Various Artists', 55.440000000000026),
#  ('Velvet Revolver', 12.870000000000001),
#  ('Vinícius De Moraes', 14.850000000000001),
#  ('Wilhelm Kempff', 0.99),
#  ('Yehudi Menuhin', 0.99),
#  ('Yo-Yo Ma', 0.99),
#  ('Zeca Pagodinho', 18.81)]

# %% [markdown]
# ## Задание 5
# Для каждой компании вывести общее количестов песен, купленных по жанру рок

# %%
# %%sql
# Select customers.Company,count(tracks.Name)
# from customers join invoices
# on customers.CustomerId = invoices.InvoiceId
# join invoice_items
# on invoices.InvoiceId = invoice_items.InvoiceId
# join tracks
# on tracks.TrackId = invoice_items.TrackId
# join genres
# on tracks.GenreId = genres.GenreId
# where genres.Name = 'Rock'
# group by customers.Company
# Out:
# Done.
# [(None, 103),
#  ('Apple Inc.', 3),
#  ('Embraer - Empresa Brasileira de Aeronáutica S.A.', 2),
#  ('Microsoft Corporation', 3),
#  ('Riotur', 7)]

# %% [markdown]
# ## Задание 6
# Вывести альбом, который является минимальным по объему(в байтах) среди альбомов со стоимостью, большей средней цены за альбом по всем альбомам с таким же жанром (если у альбома песни с нескольким жанрами, то жанром является тот, у которого наибольшее количество песен в альбоме)
